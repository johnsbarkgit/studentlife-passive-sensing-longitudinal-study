# %% [markdown]
# ##Import Statements

# %%
import os
from pathlib import Path

# %% [markdown]
# ##Raw Data Structure

# %%
p = Path("data/raw/dataset")
folders = [d.name for d in p.iterdir() if d.is_dir()]
print(folders)
